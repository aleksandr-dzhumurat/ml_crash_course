# %%
import logging
import os

import sqlite3
import pandas as pd

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(message)s",
    handlers=[
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)
logger.setLevel('INFO')

db_file = 'data/messages.db'

conn = sqlite3.connect(db_file, check_same_thread=True)

def run_sql(sql_str, db_con=conn, cols = None):
    with db_con as con:
        res = pd.DataFrame(con.execute(sql_str).fetchall(), columns=cols)
    return res
        
sql_str = """
    SELECT 
        name
    FROM 
        sqlite_master
    WHERE 
        name NOT LIKE 'sqlite_%';
"""
run_sql(sql_str, cols=['table_name'])
# Out:
#     table_name
# 0  tg_messages

# %%
TABLE_NAME = 'tg_messages'

table_df = pd.read_sql_query(f"SELECT * from {TABLE_NAME} LIMIT 10", conn)

table_df.head()
# Out:
#      id                                                msg         channel  \
# 0  2248  управляющая компания предлагает в аренду 1 одн...  rentinlimassol
# 1  2246  управляющая компания предлагает в аренду целое...  rentinlimassol
# 2  2238  управляющая компания предлагает в аренду роско...  rentinlimassol
# 3  2232  управляющая компания предлагает в аренду совре...  rentinlimassol
# 4  2224  управляющая компания предлагает в аренду роско...  rentinlimassol
#
#                            msg_hash
# 0  314c320246f78c0db8ddb8489072f7ab
# 1  6f3d312ef2c7f712ba0f761556492df0
# 2  cb3cb9c0da0195b069392b849003d84f
# 3  3f29b9e54210ea6c4ea3cafb27d04a9b
# 4  2c697381b6caac91e7b684fa34b86025

# %%
sql_str = f"""
    SELECT
        COUNT(*) as num_messages,
        CAST(AVG(length(msg))  as integer) as avg_length,
        COUNT(DISTINCT channel) num_channels
    FROM {TABLE_NAME}
    LIMIT 10
"""

pd.read_sql_query(sql_str, conn)
# Out:
#    num_messages  avg_length  num_channels
# 0         27037         324             6

# %%
from jinja2 import Template

def get_neg_samples_df():
    irrelevant_msg_ids = [
        153375, 130177, 152303, 156005, 152225, 152209, 152159, 152129,
        152831, 152766, 152740, 152697, 129161, 129139, 152628, 152556
    ]

    sql_str = Template(
        """
        SELECT 
            id, msg
        FROM {{ table }}
        WHERE id IN (
            {%- for msg_id in msg_ids -%} {{msg_id}} {{"," if not loop.last }} {% endfor %}
        )
        """
    ).render(msg_ids=irrelevant_msg_ids, table=TABLE_NAME)

    neg_samples_df = pd.read_sql_query(sql_str, conn)
    num_neg_samples = neg_samples_df.shape[0]

    logger.info('num rows: %d', num_neg_samples)
    
    return neg_samples_df

neg_samples_df = get_neg_samples_df()
neg_samples_df.head()
# Out:
# 2023-01-08 23:31:18,648 num rows: 16
#        id                                                msg
# 0  129161  продажа (собственник) лимассол   580 000 евро ...
# 1  129139  аренда город ларнака . район декелия . дом три...
# 2  152740  продажа  продается новая квартира за €310,000 ...
# 3  152129  **mandarin park: новое высотное здание в лимас...
# 4  152159  **как получить визитерскую визу на кипре? инст...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


def get_train_set(limit = -1):
    negatives_df = get_neg_samples_df()
    if limit < 0:
        num_negatives = negatives_df.shape[0]
        num_positives = int( num_negatives / 0.1)
        limit = num_positives + num_negatives
    else:
        limit = 8*10**3
    irrelevant_msg_ids = negatives_df['id'].values.tolist()
    sql_str = Template(
        """
        SELECT 
            msg,
            length(msg) as len_msg,
            CASE
                WHEN id IN (
                        {%- for msg_id in msg_ids -%} {{msg_id}} {{"," if not loop.last }} {% endfor %}
                    )
                THEN 1
                ELSE 0
            END target
        FROM {{ table }}
        ORDER BY target DESC
        LIMIT {{ limit }}
        """
    ).render(msg_ids=irrelevant_msg_ids, table=TABLE_NAME, limit=limit)

    corpus_df = pd.read_sql_query(sql_str, conn)
    
    return corpus_df

class Pandas2CSR:
    def __init__(self):
        self.vectorizer = None
        self.txt_col = None
        self.anchor_elements = None
    
    def df_to_matrix(self, input_series):
        res = input_series.values.reshape(-1).tolist()
        
        return res
    
    def fit(self, input_df, text_column='msg'):
        csr_matrix_dataset = self.df_to_matrix(input_df[text_column])
        self.txt_col = text_column
        
        logger.info('num rows: %d', len(csr_matrix_dataset))

        self.vectorizer = TfidfVectorizer()
        X = self.vectorizer.fit_transform(csr_matrix_dataset)
        logger.info('sparse matrix %s', X.shape)
        
        return X
    
    def transform(self, input_df):
        corpus = self.df_to_matrix(input_df[self.txt_col])
        X = self.vectorizer.transform(corpus)
        
        logger.info('result matrix %s', X.shape)
        
        return X
    
    def generate_features(self, neg_samples_df):
        # сохраняем якорные элементы
        if self.anchor_elements is None:
            self.anchor_elements = self.transform(neg_samples_df)
        anchor_elems

corpus_df = get_train_set()
pandas2csr = Pandas2CSR()
raw_matrix = pandas2csr.fit(corpus_df)

corpus_df.head()
# Out:
# 2023-01-08 23:31:20,151 num rows: 16
# 2023-01-08 23:31:20,184 num rows: 176
# 2023-01-08 23:31:20,201 sparse matrix (176, 2390)
#                                                  msg  len_msg  target
# 0  продажа (собственник) лимассол   580 000 евро ...     2009       1
# 1  аренда город ларнака . район декелия . дом три...      140       1
# 2  продажа  продается новая квартира за €310,000 ...      588       1
# 3  **mandarin park: новое высотное здание в лимас...      197       1
# 4  **как получить визитерскую визу на кипре? инст...       99       1

# %%
from sklearn.metrics.pairwise import euclidean_distances

neg_samples_csr = pandas2csr.transform(neg_samples_df)

distances = euclidean_distances(raw_matrix, neg_samples_csr)
logger.info(distances.shape)
# Out:
# 2023-01-08 23:31:20,943 result matrix (16, 2390)
# 2023-01-08 23:31:20,946 (176, 16)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression().fit(distances, corpus_df['target'])
# Out:
# C:\Users\79127\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
corpus_df = get_train_set(limit=8*10**3)
raw_matrix = pandas2csr.transform(corpus_df)
distances = euclidean_distances(raw_matrix, neg_samples_csr)
neg_example_proba = lr.predict_proba(distances)
# Out:
# 2023-01-08 23:31:22,734 num rows: 16
# 2023-01-08 23:31:23,096 result matrix (8000, 2390)

# %%
corpus_df['dummy_label'] = neg_example_proba[:,1]

pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.expand_frame_repr', False)

scored_corpus_df = (
    corpus_df.query("len_msg > 0")
    [['msg', 'dummy_label']]
    .sort_values(by='dummy_label', ascending=False)
)

scored_corpus_df.head(270)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           msg  dummy_label
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       **mandarin park: новое высотное здание в лимассоле **в районе гермасойя возведут элитный небоскреб. [https://dom.com.cy/live/digest-63766](https://dom.com.cy/live/digest-63766/?utm_source=telegram)     0.265801
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            **на кипре продлили налоговые льготы при реструктуризации необслуживаемых кредитов** до какого числа проблемные заемщики получили послабления? [https://dom.com.cy/live/digest-63770](https://dom.com.cy/live/digest-63770/?utm_source=telegram)     0.262643
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              **полуостров акамас: забытый рай на кипре ** особенности региона, плюсы и минусы покупки недвижимости. [https://dom.com.cy/live/lifehacks-63910](https://dom.com.cy/live/lifehacks-63910/?utm_source=telegram)     0.252452
# 3939                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              **район пейя в пафосе вскоре кардинально преобразится** в регионе реализуется масса важных инфраструктурных проектов. https://dom.com.cy/live/digest-57332/     0.218025
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   **подавляющее большинство зданий лимассола расположено в сейсмоопасной зоне** опасно ли это для жителей города? https://dom.com.cy/live/digest-63892/?utm_source=telegram     0.201085
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     **в лимассоле завершилось строительство здания для absolute institute of technical education **стоимость проекта оценивается в 8,5 млн евро. https://dom.com.cy/live/digest-63948/?utm_source=telegram     0.192891
# 4732                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                όταν παραπέμπετε οποιοδήποτε μέλος στην επένδυση sarwacapitals, δικαιούστε 5% σε κάθε κατάθεση που κάνετε από την downline σας.  για το δεύτερο επίπεδο, θα λάβετε 3% προμήθεια συνεργατών και για το τρίτο επίπεδο θα λάβετε 1% προμήθεια θυγατρικών.  μπορείτε να επανεπενδύσετε την προμήθεια σας ή να κάνετε ανάληψη ανά πάσα στιγμή.     0.189911
# 7648                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0mgmgd1     0.189911
# 2970                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      фронтенд разработка     0.189911
# 4413                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         зубной? половой?     0.189911
# 7813                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          в этом квадрате     0.189911
# 6472                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ищy сoтрудникa нa удaлённyю рaботy oплaтa 10000р в день грaфик свoбoдный  oтвeчy нa вaши вoпрocы в лc     0.189911
# 2319                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               просто в fb заходишь маркетplace и найдёшь     0.189911
# 2613                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     спам     0.189911
# 4731                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 οι αναλήψεις γίνονται άμεσα και δεν υπάρχουν κρυφές χρεώσεις, λαμβάνετε την ανάληψη σας αμέσως μετά το αίτημα, στο πορτοφόλι σας bitcoin     0.189911
# 2580                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    hello     0.189911
# 4728                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 το όνομα της εταιρείας είναι επενδυτική πλατφόρμα sarwacapitals, η sarwacapitals invest είναι μια μοναδική διαδικτυακή πλατφόρμα επενδύσεων και εξόρυξης, η οποία επιτρέπει σε ανεξάρτητους επενδυτές από όλο τον κόσμο να λαμβάνουν μερίσματα από τις συναλλαγές διαφορετικών τύπων νομισμάτων σε μεγάλα χρηματιστήρια.     0.189911
# 5314                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      х0+     0.189911
# 2959                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        /     0.189911
# 2139                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             hi everyone am victoria duke     0.189911
# 7005                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     halo     0.189911
# 3814                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                γεια σας όμορφοι άνθρωποι     0.189911
# 4443                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    dm me     0.189911
# 2389                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             είμαι καινούριος εδώ. μιλήστε με για επαγγελματική συζήτηση.     0.189911
# 2388                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        й     0.189911
# 2142                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       x3     0.189911
# 7501                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         і якщо вам потрібні гроші, щоб купити будинок dm     0.189911
# 5794                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      why     0.189911
# 7500                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   якщо вам потрібні гроші, щоб допомогти собі, напишіть мені прямо зараз     0.189911
# 2570                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ъхъёхё     0.189911
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...          ...
# 4917   телеграм группы русскоговорящих, отдыхающих и живущих в разных странах мира  • это укороченый список, полный же список смотрите в предыдущих постах этого [канала](https://t.me/tele_360chat)    австралия: @forum_australia   австрия: @avstriya_forum   азербайджан: @forum_azerbaijan   алжир: @aljir_chat  англия: @forum_england   албания: @albania_forum   аргентина: [@argentina_forum](https://t.me/slavianskiy_forum/641)   армения: [@forum_armenia](https://t.me/slavianskiy_forum/637)   афганистан: @afganistan_forum  бангладеш: @bangladesh_360  бахрейн: @bahrein_chat  барбадос: @barbados_chat  бруней: @brunei_chat  бутан: @butan_chat  ботсвана: @botsvana_chat  бельгия: @belgiya_chat  белиз: @forum_beliz   беларусь: @forum_belarus    болгария: @forum_bulgaria   босния: @bisniya  бразилия: @brazilia_forum   венесуэла: @venesyela  венгрия: @wengria_forum   вьетнам: [@forum_vietnam_rus](https://t.me/slavianskiy_forum/600)    германия: @forum_germany   гонконг: @forum_hongkong   греция: @for...     0.119642
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              **yoo limassol by philippe starck: эксклюзивный жилой комплекс в лимассоле** компания-застройщик презентовала свой новый проект. (фото) https://dom.com.cy/live/digest-56818/     0.119238
# 6974                               подборка мощнейших материалов на тему любви, отношений и секса:   подкаст: [«вернуть сексуальный интерес в отношения спустя годы супружеской жизни»](https://t.me/psypractica/539)   подкаст: ["измены. причины, можно ли простить?"](https://t.me/psypractica/532)   подкаст: ["6 причин твоего одиночества"](https://t.me/psypractica/955)   цикл:[ "сексуальность и сердечный контакт"](https://t.me/psypractica/505)   упражнение: ["5 граней моего одиночества"](https://t.me/psypractica/974)   упражнение: ["я глазами партнёра"](https://t.me/psypractica/96)   упражнение:[ "обмен энергий с партнёром"](https://t.me/psypractica/112)   упражнение:[ "поддержка, которая подходит мне. поиск оптимальной формы поддержки."](https://t.me/psypractica/601)   тренинг: ["как встретить партнёра своей мечты?"](https://t.me/psypractica/952?single)   запись прямого эфира:[ "демонстрационная сессия по работе с темой одиночества и завершения партнерской связи"](https://t.me/psypractica/979)     0.118411
# 5766                                                                  записи демонстрационных сессий по различным психотерапевтическим подходам от мэтра психологии и психотерапии — козаева никиты борисовича:  [ системно-феноменологическая терапия](https://t.me/psypractica/979) (расстановки, формат: "рефлексирующая команда", групповая динамика)   [ психоанатическая терапия](https://t.me/psypractica/764)  [ телесно-ориентированная терапия](https://t.me/psypractica/1095)  [ когнитивно-поведенческая терапия](https://t.me/psypractica/1052)  [ гипнотерапия (эриксоновский гипноз)](https://t.me/psypractica/1130)  [ экзистенциально-гуманистическая терапия](https://t.me/psypractica/928)  [ гештальт-терапия](https://t.me/psypractica/865)   с полным перечнем его компетенций, а также вузов, где он учился и преподавателей, которые вырастили его, как специалиста, можно ознакомиться здесь https://t.me/psypractica/680  для записи на индивидуальную психотерапевтическую сессию писать в личку: @psychologmoscow     0.115355
# 60                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             **кипр оказался в числе стран ес, где стоимость покупки и аренды недвижимости снизилась** eurostat опубликовал свежие данные о ценах на жилье в странах европейского союза. (статистика) https://dom.com.cy/live/digest-56806/     0.115314
# 5537                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      join sergihnoandgiovanni on viber https://invite.viber.com/?g2=aqahcexfmd8ayu%2batrnewqykus2k2snnf6mwi6ak4aj8mtbs6b%2bqyp2a7vwuk4f4     0.110833
# 4864  [​](https://telegra.ph/file/a04fee7206b49e05ce991.jpg) [​](https://telegra.ph/file/6e52680abe8ae358f1b19.jpg)[​](https://telegra.ph/file/af5878207fc41758a683b.jpg)[​](https://telegra.ph/file/599362478089b338a3a50.jpg)[​](https://telegra.ph/file/33fc417e104b08c1bfa33.jpg)[​](https://telegra.ph/file/47ddd770ab337d9a14337.jpg)[​](https://telegra.ph/file/20ea9df49b7696f76db24.jpg)**#продажа**  ******   **продаж** **пентхауса**  ****  ———————— **продажа 3-х спального просторного пентхауса с видом на море и горы с садом на крыше ruff garden  **[**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)******[**kato](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[ ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)[**polemidia ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**  **стоимость**: **577,000 €+vat **   **(торг разумный уместен) **  **общая информация:**  **обьект **№ **id: 0101** **•darua•**   **продажа нового последнего  3-х спального пенхауса с садом на крыше r...     0.110607
# 45                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 **кипр в числе лидеров по количеству проблемных ссуд среди стран ес** европейское банковское управление назвало страны с самым высоким показателем npl. (статистика) https://dom.com.cy/live/digest-56881/     0.110560
# 269                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               кипр, встречай **интернет-магазин epl diamond**!   лучшие ювелирные изделия всемирного бренда теперь доступны к заказу он-лайн. покупайте ювелирные украшения на сайте [cy.epldiamond.com](http://cy.epldiamond.com/?utm_source=tgkipr_arenda) и получайте подарки!   приятные цены и летние скидки вас порадуют! доставка по городу лимассол бесплатная, по кипру бесплатная при сумме заказа от 300 евро.     0.110316
# 4862   [​](https://telegra.ph/file/6e52680abe8ae358f1b19.jpg)[​](https://telegra.ph/file/af5878207fc41758a683b.jpg)[​](https://telegra.ph/file/599362478089b338a3a50.jpg)[​](https://telegra.ph/file/33fc417e104b08c1bfa33.jpg)[​](https://telegra.ph/file/47ddd770ab337d9a14337.jpg)[​](https://telegra.ph/file/20ea9df49b7696f76db24.jpg)**#продажа**  ******   **продаж** **пентхауса**  ****  ———————— **продажа 3-х спального просторного пентхауса с видом на море и горы с садом на крыше ruff garden  **[**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)******[**kato](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[ ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)[**polemidia ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**  **стоимость**: **577,000 €+vat **   **(торг разумный уместен) **  **общая информация:**  **обьект **№ **id: 0101** **•darua•**  ** продажа нового последнего 3-х спального пенхауса с садом на крыше ruff garden** **   • 3 спальни (в каждой спальне  есть с...     0.109868
# 6047                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     **в каком районе ларнаки лучше покупать недвижимость для жизни, а в каком для сдачи в аренду? **кто-то делает выбор в пользу вида из окна, кто-то готов жить в историческом здании, украшенном винтажной мебелью, а кто-то хочет всего и сразу. https://dom.com.cy/live/blogs-57618/     0.109132
# 4893  [​](https://telegra.ph/file/c37921137eb3df87a93c7.jpg)[​](https://telegra.ph/file/991f349626b2795c39bb6.jpg)[​](https://telegra.ph/file/a804131b096b1967a53bd.jpg)[​](https://telegra.ph/file/309ae2f7b52d34ba500f9.jpg)**#продажа**  ******  **продаж** **пентхауса  **  ———————— **продажа 3-х спального роскошного пентхауса **[**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)******[**germasoia village](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)** **стоимость**:  **790.000 € +ндс**  **общая информация:**  **обьект **№ **id: 6301** **•ero• ** **• **[продается ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**•** **3х-спальный роскошный пентхаус на 4-этаже.** **• с видом на море и горы.** **• лимассол гермасойя (деревня)** **• стоимость: 790.000 € +ндс** **• с видом на море и горы.** **•** **с террасой на крыше roof garden** **•** **с собственным бассейном. • общий бассейн в комплексе**.  **•** **в пяти минутах езды к пляжу 3 км • три минуты езды к тур зоне **  **оп...     0.108294
# 5545                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             https://m.bazaraki.com/adv/4283936_2-bedroom-ground-floor-apartment-to-rent/     0.108143
# 7177                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                i received my profits without delay and any attachment of fees now i can start making money with the help of you mrs.   https://telegram.me/+ba_ux5po8umwnty0 https://telegram.me/+ba_ux5po8umwnty0 https://telegram.me/+ba_ux5po8umwnty0     0.106712
# 4625  [​](https://telegra.ph/file/8388ab0aff36200470150.jpg)[​](https://telegra.ph/file/89c0136e2c0d406fe7156.jpg)**#аренда**  ******   **аренд** **пентхауса   **  ———————— **аренда 3-х спального современного пентхауса **[**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)******[**potamos germasoia ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)** **возле гостинцы аполлония   стоимость: 5.500 €** **( два депозит одна аренда при оплате вперед стоимость будет снижена до  5**.**000 € )**  **общая информация:**  **обьект **№ **id: 0305** **•sa•**  **• современный пентхаус в совершено новом красивом доме,на последнем этаже, в 150-200 метрах от моря. **             [**описание ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)****** **• общая крытая площадь **[**132 ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[м²](https://telegra.ph/file/aece5c1a241defa34fa95.jpg) **• kрытые веранды **[**39 ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[м²](https://telegra.p...     0.106707
# 5307                                                                                                                                                                                                                          друзья  на канале[ "психея"](https://t.me/psypractica) существует очень [удобная навигация](https://t.me/psypractica/9), к которой вы всегда можете перейти через закреплëнное сообщение.   также, существует[ основной канал,](https://t.me/psychologmsc) где есть списки всех:  [ упражнений](https://t.me/psychologmsc/115)  [ подкастов](https://t.me/psychologmsc/116)  [ тренингов](https://t.me/psychologmsc/120)  [ кейсов](https://t.me/psychologmsc/122)  [ полезные материалы (текстовые)](https://t.me/psypractica/50)  [ видеообсуждения](https://t.me/psychologmsc/126)  ️также у никиты борисовича, автора канала, есть бот с метафорическими картами — @psychea_robot  также всë интересующее вы можете искать по хэштегам и ключевым словам в поиске  (три точки в правом верхнем углу экрана)     0.106561
# 6467                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   𝗺𝐚𝐤𝐢𝐧𝐠 𝗺𝗼𝐧𝐞𝐲 𝐟𝐫𝗼𝗺 𝐭𝐡𝐞 𝐜𝗼𝗺𝐟𝗼𝐫𝐭 𝗼𝐟 𝗺𝐲 𝐡𝗼𝗺𝐞 𝐛𝐲 𝐂𝐫𝐲𝐭𝗼𝐓𝐫𝐚𝐝𝐢𝐧𝐠!  𝐘𝗼𝐮 𝐭𝐡𝐞 𝐛𝐞𝐬t 𝐓𝐡𝐚𝐧𝐤 𝐲𝐨𝐮 𝐟𝐨𝐫 𝐛𝐞𝐢𝐧𝐠 𝐬𝐨 𝐠𝐞𝐧𝐞𝐫𝐨𝐮𝐬, 𝐭𝐡𝐨𝐮𝐠𝐡𝐭𝐟𝐮𝐥 𝐚𝐧𝐝 𝐬𝐨 𝐭𝐫𝐮𝐞.  𝐖𝐢𝐭𝐡 $3, 𝟑𝟓𝟎 𝐬𝐭𝐚𝐫𝐭-𝐮𝐩 𝐢 𝐦𝐚𝐝𝐞 $𝟑𝟏,𝟏𝟎𝟎 𝐓𝐡𝐚𝐧𝐤 𝐲𝐨𝐮 𝐟𝐨𝐫 𝐤𝐞𝐞𝐩𝐢𝐧𝐠 𝐲𝐨𝐮𝐫 𝐰𝐨𝐫𝐝𝐬 𝐚𝐧𝐝 𝐛𝐞𝐢𝐧𝐠 𝐭𝐡𝐞 𝐫𝐞𝐚𝐥 𝐲𝐨𝐮  @mr_jaysonlewis_option_trade click on the link and ask the manager how   https://t.me/joinchat/7h8sggtmiivkzjbk https://t.me/joinchat/7h8sggtmiivkzjbk     0.106493
# 4875   [​](https://telegra.ph/file/6e52680abe8ae358f1b19.jpg)[​](https://telegra.ph/file/af5878207fc41758a683b.jpg)[​](https://telegra.ph/file/599362478089b338a3a50.jpg)[​](https://telegra.ph/file/33fc417e104b08c1bfa33.jpg)[​](https://telegra.ph/file/47ddd770ab337d9a14337.jpg)[​](https://telegra.ph/file/20ea9df49b7696f76db24.jpg)**#продажа**  ******  **продаж****партамента** ****  ———————— **продажа 3-х спального просторного апартамента **[**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)******[**mesa](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[ ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)[**geitonia](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)** **стоимость**: **245,000 €  не облагается **—**ндс (торг разумный уместен возможна частичная оплата рублями в россии) **  **общая информация:**  **обьект **№ **id: 0101** **•tan**_**ir•**   **продажа 3-сп**. **квартиры на  7-этаже в 10 этажном доме.** **с панорамным красивым видом на горы,город и море. лимас...     0.105922
# 4892  [​](https://telegra.ph/file/2f0d575f756bb3ab969be.jpg)[​](https://telegra.ph/file/9997e507659d2de497f44.jpg)[​](https://telegra.ph/file/4a8515b52a207de05ea92.jpg)[​](https://telegra.ph/file/c4a016b76ec9831c48492.jpg)[​](https://telegra.ph/file/c37921137eb3df87a93c7.jpg)[​](https://telegra.ph/file/991f349626b2795c39bb6.jpg)[​](https://telegra.ph/file/a804131b096b1967a53bd.jpg)[​](https://telegra.ph/file/309ae2f7b52d34ba500f9.jpg)**#продажа** ******  **продаж** **участка с **  ———————— **продажа 4-х спального отличного финского домика из бруса и не достроенного  3-х этжног** **дома +цокольный этаж на** **большом участке земли на горе общей площадью 37 соток. **[**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)******[**village phini ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)** **стоимость**: **600.000 € без ндс **(стоимость снизили на 100к)**  торг уместен (оформлено на компанию, возможен купить за крипта валюту биткоин и другую валюту** ,**вместе с компанией.)*...     0.105911
# 7869  [​](https://telegra.ph/file/8388ab0aff36200470150.jpg)[​](https://telegra.ph/file/89c0136e2c0d406fe7156.jpg)**#арендаофиса** **#лимассол**                 **аренд** **офиса   **  ———————— **аренда современного** **офиса **[**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)******[**neapolis linopetra](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)****  стоимость: 10.400 €** **(три депозита одна аренда минимальный срок аренды 3 года)**  **общая информация:**  **обьект **№ **id: 0805** **•mika•**             **описание ** **• общая площадь **[**312 ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[м²](https://telegra.ph/file/aece5c1a241defa34fa95.jpg) **• внутренняя площадь **[**260](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[ м²](https://telegra.ph/file/aece5c1a241defa34fa95.jpg) **• веранда **[**52](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[ м²](https://telegra.ph/file/aece5c1a241defa34fa95.jpg) **• 4 крытых парковочных места————————————————...     0.105350
# 6097  [​](https://telegra.ph/file/af5878207fc41758a683b.jpg)[​](https://telegra.ph/file/599362478089b338a3a50.jpg)[​](https://telegra.ph/file/33fc417e104b08c1bfa33.jpg)[​](https://telegra.ph/file/47ddd770ab337d9a14337.jpg)[​](https://telegra.ph/file/20ea9df49b7696f76db24.jpg)**#аренда**  ******  **аренд****партамента** ****  ————————  **аренда 3-х спального просторного апартамента **[**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)******[**mesa](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[ ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)[**geitonia](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**  **стоимость**: **1.600 € ** **(сдается с середины сентября. возможно с животными. одна аренда ,два депозита)**  **общая информация:**  **обьект **№ **id: 0101** **•tan**_**ir•**  **аренда 3-сп**. **квартиры на  7-этаже в 10 этажном доме.** **с панорамным красивым видом на горы,город и море. лимассол**  **меса геитония ** **рядом hotel  ajax в 10-15 минутах в пеше...     0.105341
# 4868  **#продажалимассол**  ****** **продаж** **люксовых 2-х рядом земельных участков с** **панорамным ** **видом на море ** ———————— [**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[ ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)[**agios ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[ ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)[**tychonas](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**** ****стоимость**: **600.000 €  одного участка,второй столько же стоит. (торг разумный уместен)**  **общая информация:**  **обьект **№ **id: 0304** **•yan_2•  •** [продается](https://telegra.ph/file/aece5c1a241defa34fa95.jpg) **•2 земельных участка площадью каждый  **[**900 ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[м²](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)  **• площадь застройки **[**30 ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)****% • титул есть в наличии на землю • рядом с участком по соседству уже есть построенные виллы. ...     0.105241
# 4867  **#продажа**  ****** **продаж** **люксовой виллы** **с** **потрясающий** **видом на море ** ———————— [**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[ ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)[**agios ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[ ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)[**tychonas](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**** ** **стоимость**: **1**.**800 000 €  без vat (торг разумный уместен)**  **общая информация:**  **обьект **№ **id: 0303** **•yan_2•  •** [продается](https://telegra.ph/file/aece5c1a241defa34fa95.jpg) **•** **3х-спальная вилла под чистовую отделку/ремонт. • вилла построена на земельном участке площадью  **[**900 ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[м²](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)** • общая площадь дома **[**600 ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[м²](https://telegra.ph/file/aece5c1a241defa34fa95.jpg) **• 3 спальни (на втором эт...     0.104794
# 4894  ******** ** [​](https://telegra.ph/file/0948a27872490e8a4a268.jpg)**#продажаземельногоучастка** **продаж** **зем**е**льного учаска** ———————— **#продажа**** **[**участка 12 000 ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**[м²](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)** **[**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)******[**agios tychonas ](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)** **стоимость 1**.**500 000 € **  **общая информация:**  **обьект **№ **id: 0101 • mika** **•** **• **продаётся земельный участок  с шикарным панорамным видом на море и город ,под инвестицию , в **агиос тихонас в **семи минутах от хайвей. **• **общая площадь [12 000 м²](https://telegra.ph/file/aece5c1a241defa34fa95.jpg) **•  **площадь застройки [**5](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)** %   **• **дорога подведена к участку,а также рядом проведена электросеть,вся инфраструктура рядом развита.   эти участок может быть интересен тем кто желает ин...     0.104575
# 7677                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     𝐈 𝐦𝐮𝐬𝐭 𝐜𝐨𝐧𝐟𝐞𝐬𝐬 𝐧𝐨𝐛𝐨𝐝𝐲 𝐡𝐚𝐧𝐝𝐥𝐞𝐬 𝐦𝐲 𝐭𝐫𝐚𝐝𝐞 𝐚𝐜𝐜𝐨𝐮𝐧𝐭 𝐥𝐢𝐤𝐞 𝐲𝐨𝐮 𝐝𝐨 , 𝐈’𝐦 𝐩𝐫𝐢𝐯𝐢𝐥𝐞𝐠𝐞𝐝 𝐭𝐨 𝐰𝐨𝐫𝐤 𝐰𝐢𝐭𝐡 𝐲𝐨𝐮…𝐲𝐨𝐮’𝐫𝐞 𝐢𝐧𝐝𝐞𝐞𝐝 𝐨𝐧𝐞 𝐨𝐟 𝐭𝐡𝐞 𝐛𝐞𝐬𝐭 𝐭𝐫𝐚𝐝𝐞𝐫.𝐈 𝐧𝐞𝐯𝐞𝐫 𝐤𝐧𝐞𝐰 𝐈 𝐰𝐢𝐥𝐥 𝐛𝐞 𝐚𝐛𝐥𝐞 𝐭𝐨 𝐩𝐚𝐲 𝐨𝐟𝐟 𝐦𝐲 𝐛𝐢𝐥𝐥𝐬 , 𝐈 𝐢𝐧𝐯𝐞𝐬𝐭𝐞𝐝 €𝟓𝟎𝟎 in bitcoins 𝐚𝐧𝐝 𝐈 𝐠𝐨𝐭 𝐦𝐲 𝐩𝐫𝐨𝐟𝐢𝐭 𝐨𝐟 €𝟒,𝟎𝟎𝟎 𝐚𝐧𝐝 𝐠𝐞𝐭 𝐭𝐨 𝐬𝐭𝐚𝐧𝐝 𝐚𝐠𝐚𝐢𝐧 𝐢𝐧 𝐥𝐢𝐟𝐞 …𝐈 𝐰𝐚𝐧𝐭 𝐲𝐨𝐮 𝐠𝐮𝐲𝐬 𝐭𝐨 𝐡𝐞𝐥𝐩 𝐦𝐞 𝐚𝐩𝐩𝐫𝐞𝐜𝐢𝐚𝐭𝐞 , 𝐢𝐧𝐯𝐞𝐬𝐭𝐢𝐧𝐠 𝐚𝐧𝐝 𝐠𝐞𝐭𝐭𝐢𝐧𝐠 𝐫𝐞𝐭𝐮𝐫𝐧𝐬 𝐢𝐬 all 𝐢 𝐞𝐯𝐞𝐫 𝐰𝐚𝐧𝐭𝐞𝐝 𝐈 𝐟𝐢𝐧𝐚𝐥𝐥𝐲 𝐟𝐨𝐮𝐧𝐝 𝐢𝐭 𝐆𝐨𝐝 bless https://t.me/+rkgxl2ug9ddlzmm8     0.104347
# 4883  ******** ** [​](https://telegra.ph/file/0948a27872490e8a4a268.jpg)**#продажаземельныхучастков** **продаж** **участков земли** ———————— **продажа** **2х участков 20000 м2  **[**limassol](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)******[**mouttagiaka](https://telegra.ph/file/aece5c1a241defa34fa95.jpg)**  **стоимость  двух   4.000 000 €  стоимость одног 2.000 000 €**  **общая информация:**  **обьект **№ **id: 0203 larkrоft •** **• **продаётся два участка под инвестиции , в [мутойяке трех](https://telegra.ph/file/aece5c1a241defa34fa95.jpg) минутах от хайвей с панорамным видом на море. **• **общая площадь [20 000 м²](https://telegra.ph/file/aece5c1a241defa34fa95.jpg) **•  **площадь застройки [40](https://telegra.ph/file/aece5c1a241defa34fa95.jpg) % .  **• **дорога подведена к участкам, развитая инфраструктура рядом.   титул в наличии на одного владельца. эти участки могут быть интересны тем кто хочет инвестировать в девелоперские проекты, или сами построить на продажу. возможно ...     0.103611
# 2894                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     добрый день! крутая компания ищет с кем разделить большой офис. можно снимать частями (всего 3 офиса). буду рада ответить на все ваши вопросы https://www.bazaraki.com/adv/4134632_office-in-meneou/     0.103426
# 4766                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       faire le bon choix est le début du bonheur ne vous occupez pas de toutes ces fausses plateformes autour rejoignez nexfar et tradez l_esprit libre de frais inutiles lorsque l_investisseur est sur le point de se retirer.  https://guest.link/gmi     0.103147
# 4679                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       **аренда | 3-сп квартира | 130 м2 | kanika enaerios, limassol | €2.500** уютные апартаменты с видом на море • этаж: 5 • этажность: 7 • расстояние до моря — 100 м • вид на море • бытовая техника • мебель • кондиционирование воздуха • двойные стеклопакеты • паркет • парковка • объект №49765 обращайтесь к нам для получения дополнительной информации (ru / eng / gr) https://dom.com.cy/catalog/rent/49765/     0.102333
# 186                                                                                                                                                                                                                                             группы по кипру   **телеграм** • основная: t.me/forum_cyprus • женская: t.me/cyprus_woman • родители и дети: t.me/kipr_deti • жильё: t.me/kipr_arenda • работа: t.me/kipr_rabota • it чат: t.me/kipr_it • барахолка: t.me/cyprus_market • еда: t.me/eda_cyprus • обмен валют и крипта: t.me/cyprus_360 так же есть закрытый чат экспатов   чаты северного кипра: t.me/kipr_severnii t.me/kipr_chat   **whatsapp / viber** чаты: http://trip360.shop/chat   **вконтакте** • аренда жилья: vk.com/arenda.kipr • попутчики - знакомства: vk.com/popytchikinakipr • работа: vk.com/kipr_rabota • барахолка: vk.com/kipr_baraholka   **важно**    такие группы у нас есть по 110 странам мира, ссылки здесь: t.me/tele_360chat  канал новостей проекта: t.me/slavianskiy_forum *анонсы новых групп     0.102175
#
# [270 rows x 2 columns]

# %%
scored_corpus_df.to_csv('data/scored_corpus.csv', index=False)
logger.info('%d lines saved', scored_corpus_df.shape[0])
# Out:
# 2023-01-08 23:31:27,156 6542 lines saved

# %%
df = pd.read_csv('data/labeled_data_corpus.csv')

train_df = df[df['subset'] == 'train']
test_df = df[df['subset'] == 'test']
print(train_df.shape[0], train_df['label'].mean(), test_df.shape[0], test_df['label'].mean())

df.head()
# Out:
# 5233 0.20045862793808522 1309 0.20091673032849502
#    msg_id                                                                                                                                                                                                                                                                                                                                                                                                                                                         msg  label subset
# 0       0                                                                                                                                                                                                                                                                    здравствуйте. ишу 2х спальную квартиру в лимассоле. желательно гермасойя. семья из 2х взрослых и 2х детей. без животных. на длительный срок, бюджет до 1000-1500 евро. предложения в лс.      0  train
# 1       1                                                                                                                                                                                                                                                                                                                                                                  #сниму  комнату в лимассоле или недалеко от него. с начала августа. любые предложения в лс      0  train
# 2       2                                                                                                                                                                                                                                                                                                                                                                                                                               мошенник риэлторским услугам.      0  train
# 3       3  **sales**    reg.1053 lic.489/e **stylish apartment with sea view  kissonerga. paphos** •total area: 85 m2  + balcony  •bedrooms:  2 •bathrooms: 1 **€ 120,000** we have a lot to offer  ================ **продажа**  reg.1053 lic.489/e **стильные апартаменты вид на море  •••kissonerga. пафос. ** •общая площадь: 85м2 + балкон •спальни: 2 •ванные комнаты: 1 **€ 120 000 ****+35726935826****  директ telegram 24/7** у нас есть что вам предложить      0  train
# 4       4                                                                                                                                                                                                                                                                                                                                     важно: [valerii korol](tg://user?id=193474890), если ты не бот и не спамер, пройди проверку, нажав на кнопку, где есть       0  train

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']

grid = {
    'max_df': np.arange(0.01, 1.0, 0.01),
    'min_df': np.arange(1, 20, 1),
}

best_params = {'max_df': None, 'min_df': None}
best_score = 0.0

num_iters = len(ParameterGrid(grid))

cnt = 0
for param_values in ParameterGrid(grid):
    # fit 
    vectorizer = TfidfVectorizer(**param_values).fit(X_train)
    X_train_csr = vectorizer.transform(X_train)
    lr = LogisticRegression().fit(X_train_csr, y_train)
    # predict
    X_test_csr = vectorizer.transform(X_test)
    y_pred = lr.predict(X_test_csr)
    cur_score = f1_score(y_true, y_pred)
    if cur_score > best_score:
        best_score = cur_score
        best_params.update(param_values)
    if cnt % 250 == 0:
        logging.info(
            'iteration: %d of %d; %s; best_score= %.4f',
            cnt, num_iters, param_values, best_score
        )
    cnt = cnt + 1
print('best params: %s, best_score %.4f', best_params, best_score)
# Out:
# C:\Users\79127\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 2023-01-08 10:46:46,876 iteration: 0 of 1881; {'max_df': 0.01, 'min_df': 1}; best_score= 0.6209
# 2023-01-08 10:49:04,406 iteration: 250 of 1881; {'max_df': 0.14, 'min_df': 4}; best_score= 0.8549
# 2023-01-08 10:51:26,067 iteration: 500 of 1881; {'max_df': 0.27, 'min_df': 7}; best_score= 0.8605
# 2023-01-08 10:53:48,101 iteration: 750 of 1881; {'max_df': 0.4, 'min_df': 10}; best_score= 0.8605
# 2023-01-08 10:56:05,337 iteration: 1000 of 1881; {'max_df': 0.53, 'min_df': 13}; best_score= 0.8605
# 2023-01-08 10:58:29,749 iteration: 1250 of 1881; {'max_df': 0.66, 'min_df': 16}; best_score= 0.8605
# 2023-01-08 11:01:04,276 iteration: 1500 of 1881; {'max_df': 0.79, 'min_df': 19}; best_score= 0.8605
# 2023-01-08 11:03:36,671 iteration: 1750 of 1881; {'max_df': 0.93, 'min_df': 3}; best_score= 0.8605
# best params: %s, best_score %.4f {'max_df': 0.16, 'min_df': 14} 0.8605108055009824

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
#from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']

grid = {
    'max_df': np.arange(0.01, 0.2, 0.01),
    'min_df': np.arange(1, 15, 1),
}

best_params = {'max_df': None, 'min_df': None}
best_score = 0.0

num_iters = len(ParameterGrid(grid))

cnt = 0
for param_values in ParameterGrid(grid):
    # fit 
    vectorizer = TfidfVectorizer(**param_values).fit(X_train)
    X_train_csr = vectorizer.transform(X_train)
    lr = LogisticRegression().fit(X_train_csr, y_train)
    #gbr = GradientBoostingRegressor(random_state=0).fit(X_train_csr, y_train)
    # predict
    X_test_csr = vectorizer.transform(X_test)
    y_pred = lr.predict(X_test_csr)
    cur_score = f1_score(y_true, y_pred)
    if cur_score > best_score:
        best_score = cur_score
        best_params.update(param_values)
    if cnt % 250 == 0:
        logging.info(
            'iteration: %d of %d; %s; best_score= %.4f',
            cnt, num_iters, param_values, best_score
        )
    cnt = cnt + 1
print('best params: %s, best_score %.4f', best_params, best_score)
# Out:
# C:\Users\79127\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 2023-01-08 11:57:51,289 iteration: 0 of 266; {'max_df': 0.01, 'min_df': 1}; best_score= 0.6209
# 2023-01-08 12:06:01,913 iteration: 250 of 266; {'max_df': 0.18000000000000002, 'min_df': 13}; best_score= 0.8605
# best params: %s, best_score %.4f {'max_df': 0.16, 'min_df': 14} 0.8605108055009824

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
#from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']

grid = {
    'max_df': np.arange(0.1, 0.2, 0.01),
    'min_df': np.arange(1, 15, 1),
}

best_params = {'max_df': None, 'min_df': None}
best_score = 0.0

num_iters = len(ParameterGrid(grid))

cnt = 0
for param_values in ParameterGrid(grid):
    # fit 
    vectorizer = TfidfVectorizer(**param_values).fit(X_train)
    X_train_csr = vectorizer.transform(X_train)
    lr = LogisticRegression().fit(X_train_csr, y_train)
    #gbr = GradientBoostingRegressor(random_state=0).fit(X_train_csr, y_train)
    # predict
    X_test_csr = vectorizer.transform(X_test)
    y_pred = lr.predict(X_test_csr)
    cur_score = f1_score(y_true, y_pred)
    if cur_score > best_score:
        best_score = cur_score
        best_params.update(param_values)
    if cnt % 250 == 0:
        logging.info(
            'iteration: %d of %d; %s; best_score= %.4f',
            cnt, num_iters, param_values, best_score
        )
    cnt = cnt + 1
print('best params: %s, best_score %.4f', best_params, best_score)
# Out:
# 2023-01-08 13:13:28,172 iteration: 0 of 140; {'max_df': 0.1, 'min_df': 1}; best_score= 0.8247
# best params: %s, best_score %.4f {'max_df': 0.15999999999999998, 'min_df': 14} 0.8605108055009824

# %%
df.reset_index(drop=True).rename(columns={'index': 'msg_id'}).head()
# Out:
#    msg_id                                                                                                                                                                                                                                                                                                                                                                                                                                                         msg  label subset
# 0       0                                                                                                                                                                                                                                                                    здравствуйте. ишу 2х спальную квартиру в лимассоле. желательно гермасойя. семья из 2х взрослых и 2х детей. без животных. на длительный срок, бюджет до 1000-1500 евро. предложения в лс.      0  train
# 1       1                                                                                                                                                                                                                                                                                                                                                                  #сниму  комнату в лимассоле или недалеко от него. с начала августа. любые предложения в лс      0  train
# 2       2                                                                                                                                                                                                                                                                                                                                                                                                                               мошенник риэлторским услугам.      0  train
# 3       3  **sales**    reg.1053 lic.489/e **stylish apartment with sea view  kissonerga. paphos** •total area: 85 m2  + balcony  •bedrooms:  2 •bathrooms: 1 **€ 120,000** we have a lot to offer  ================ **продажа**  reg.1053 lic.489/e **стильные апартаменты вид на море  •••kissonerga. пафос. ** •общая площадь: 85м2 + балкон •спальни: 2 •ванные комнаты: 1 **€ 120 000 ****+35726935826****  директ telegram 24/7** у нас есть что вам предложить      0  train
# 4       4                                                                                                                                                                                                                                                                                                                                     важно: [valerii korol](tg://user?id=193474890), если ты не бот и не спамер, пройди проверку, нажав на кнопку, где есть       0  train

# %%
# Out:
# 2023-01-08 15:05:28,109 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# 2023-01-08 15:06:22,518 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# 2023-01-08 15:07:18,158 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# 2023-01-08 15:08:14,006 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# 2023-01-08 15:09:09,305 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# best params: %s, best_score %.4f {'max_df': 0.16, 'min_df': 4} 0.8638132295719844 0.1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']

grid = {
    'max_df': np.arange(0.16, 0.17, 0.01),
    'min_df': np.arange(4, 5, 1),
}

best_params = {'max_df': None, 'min_df': None}
best_score = 0.0

num_iters = len(ParameterGrid(grid))

cnt = 0
for param_values in ParameterGrid(grid):
    # fit 
    for n_es in np.arange(450, 551, 25):
        vectorizer = TfidfVectorizer(**param_values).fit(X_train)
        X_train_csr = vectorizer.transform(X_train)
        #lr = LogisticRegression().fit(X_train_csr, y_train)
        gbr = GradientBoostingRegressor(random_state=1, n_estimators=n_es, learning_rate=best_l_r).fit(X_train_csr, y_train)
        # predict
        X_test_csr = vectorizer.transform(X_test)
        y_pred = gbr.predict(X_test_csr)
        y_pred = [0 if i < 0.5 else 1 for i in y_pred]
        cur_score = f1_score(y_true, y_pred)
        if cur_score > best_score:
            best_score = cur_score
            best_params.update(param_values)
            best_n_es = n_es
        if cnt % 250 == 0:
            logging.info(
                'iteration: %d of %d; %s; best_score= %.4f',
                cnt, num_iters, param_values, best_score
            )
    cnt = cnt + 1
print('best params: %s, best_score %.4f', best_params, best_score, best_n_es)
# Out:
# 2023-01-08 15:14:44,102 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8599
# 2023-01-08 15:15:37,405 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8621
# 2023-01-08 15:16:33,400 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# 2023-01-08 15:17:32,534 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# 2023-01-08 15:18:34,396 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# best params: %s, best_score %.4f {'max_df': 0.16, 'min_df': 4} 0.8638132295719844 500

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']

grid = {
    'max_df': np.arange(0.16, 0.17, 0.01),
    'min_df': np.arange(4, 5, 1),
}

best_params = {'max_df': None, 'min_df': None}
best_score = 0.0

num_iters = len(ParameterGrid(grid))

cnt = 0
for param_values in ParameterGrid(grid):
    # fit 
    for l_r in np.arange(0.05, 0.151, 0.025):
        vectorizer = TfidfVectorizer(**param_values).fit(X_train)
        X_train_csr = vectorizer.transform(X_train)
        #lr = LogisticRegression().fit(X_train_csr, y_train)
        gbr = GradientBoostingRegressor(random_state=1, n_estimators=best_n_es, learning_rate=l_r).fit(X_train_csr, y_train)
        # predict
        X_test_csr = vectorizer.transform(X_test)
        y_pred = gbr.predict(X_test_csr)
        y_pred = [0 if i < 0.5 else 1 for i in y_pred]
        cur_score = f1_score(y_true, y_pred)
        if cur_score > best_score:
            best_score = cur_score
            best_params.update(param_values)
            best_l_r = l_r
        if cnt % 250 == 0:
            logging.info(
                'iteration: %d of %d; %s; best_score= %.4f',
                cnt, num_iters, param_values, best_score
            )
    cnt = cnt + 1
print('best params: %s, best_score %.4f', best_params, best_score, best_l_r)
# Out:
# 2023-01-08 15:41:32,400 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8527
# 2023-01-08 15:42:17,791 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8588
# 2023-01-08 15:43:02,766 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# 2023-01-08 15:43:47,482 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# 2023-01-08 15:44:32,101 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# best params: %s, best_score %.4f {'max_df': 0.16, 'min_df': 4} 0.8638132295719844 0.10000000000000002

# %%
best_n_es = 500
best_l_r = 0.1

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']

grid = {
    'max_df': np.arange(0.16, 0.17, 0.01),
    'min_df': np.arange(4, 5, 1),
}

best_params = {'max_df': None, 'min_df': None}
best_score = 0.0

num_iters = len(ParameterGrid(grid))

cnt = 0
for param_values in ParameterGrid(grid):
    # fit 
    for d in np.arange(4, 10, 1):
        vectorizer = TfidfVectorizer(**param_values).fit(X_train)
        X_train_csr = vectorizer.transform(X_train)
        #lr = LogisticRegression().fit(X_train_csr, y_train)
        gbr = GradientBoostingRegressor(random_state=1, n_estimators=best_n_es, learning_rate=best_l_r, max_depth=d).fit(X_train_csr, y_train)
        # predict
        X_test_csr = vectorizer.transform(X_test)
        y_pred = gbr.predict(X_test_csr)
        y_pred = [0 if i < 0.5 else 1 for i in y_pred]
        cur_score = f1_score(y_true, y_pred)
        if cur_score > best_score:
            best_score = cur_score
            best_params.update(param_values)
            best_d = d
        if cnt % 250 == 0:
            logging.info(
                'iteration: %d of %d; %s; best_score= %.4f',
                cnt, num_iters, param_values, best_score
            )
    cnt = cnt + 1
print('best params: %s, best_score %.4f', best_params, best_score, best_d)
# Out:
# 2023-01-08 16:28:48,493 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8638
# 2023-01-08 16:30:18,291 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8654
# 2023-01-08 16:32:06,421 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8654
# 2023-01-08 16:34:10,017 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8654
# 2023-01-08 16:36:32,718 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8654
# 2023-01-08 16:39:14,381 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8654
# best params: %s, best_score %.4f {'max_df': 0.17, 'min_df': 4} 0.8675623800383877 8

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']

grid = {
    'max_df': np.arange(0.16, 0.17, 0.01),
    'min_df': np.arange(4, 5, 1),
}

best_params = {'max_df': None, 'min_df': None}
best_score = 0.0

num_iters = len(ParameterGrid(grid))

cnt = 0
for param_values in ParameterGrid(grid):
    # fit 
    for rs in np.arange(3, 10, 1):
        vectorizer = TfidfVectorizer(**param_values).fit(X_train)
        X_train_csr = vectorizer.transform(X_train)
        #lr = LogisticRegression().fit(X_train_csr, y_train)
        gbr = GradientBoostingRegressor(random_state=rs, n_estimators=best_n_es, max_depth=best_d).fit(X_train_csr, y_train)
        # predict
        X_test_csr = vectorizer.transform(X_test)
        y_pred = gbr.predict(X_test_csr)
        y_pred = [0 if i < 0.5 else 1 for i in y_pred]
        cur_score = f1_score(y_true, y_pred)
        if cur_score > best_score:
            best_score = cur_score
            best_params.update(param_values)
            best_rs = rs
        if cnt % 250 == 0:
            logging.info(
                'iteration: %d of %d; %s; best_score= %.4f',
                cnt, num_iters, param_values, best_score
            )
    cnt = cnt + 1
print('best params: %s, best_score %.4f', best_params, best_score, best_rs)
# Out:
# 2023-01-08 17:41:15,839 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8627
# 2023-01-08 17:41:59,091 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8637
# 2023-01-08 17:42:42,143 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8681
# 2023-01-08 17:43:25,148 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8681
# 2023-01-08 17:44:08,252 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8681
# 2023-01-08 17:44:50,581 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8681
# 2023-01-08 17:45:32,869 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8681
# best params: %s, best_score %.4f {'max_df': 0.16, 'min_df': 4} 0.8680688336520077 5

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']

grid = {
    'max_df': np.arange(0.15, 0.18, 0.01),
    'min_df': np.arange(4, 5, 1),
}

best_params = {'max_df': None, 'min_df': None}
best_score = 0.0

num_iters = len(ParameterGrid(grid))

cnt = 0
for param_values in ParameterGrid(grid):
    # fit 
    for d in np.arange(8, 10, 1):
        vectorizer = TfidfVectorizer(**param_values).fit(X_train)
        X_train_csr = vectorizer.transform(X_train)
        #lr = LogisticRegression().fit(X_train_csr, y_train)
        gbr = GradientBoostingRegressor(random_state=best_rs, n_estimators=best_n_es, max_depth=d).fit(X_train_csr, y_train)
        # predict
        X_test_csr = vectorizer.transform(X_test)
        y_pred = gbr.predict(X_test_csr)
        y_pred = [0 if i < 0.5 else 1 for i in y_pred]
        cur_score = f1_score(y_true, y_pred)
        if cur_score > best_score:
            best_score = cur_score
            best_params.update(param_values)
            best_d = d
        if cnt % 250 == 0:
            logging.info(
                'iteration: %d of %d; %s; best_score= %.4f',
                cnt, num_iters, param_values, best_score
            )
    cnt = cnt + 1
print('best params: %s, best_score %.4f', best_params, best_score, best_d)
# Out:
# 2023-01-08 18:49:37,428 iteration: 0 of 3; {'max_df': 0.15, 'min_df': 4}; best_score= 0.8423
# 2023-01-08 18:52:12,685 iteration: 0 of 3; {'max_df': 0.15, 'min_df': 4}; best_score= 0.8423
# best params: %s, best_score %.4f {'max_df': 0.16, 'min_df': 4} 0.8680688336520077 8

# %%
best_rs = 5
best_n_es = 500
best_d = 8

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']

grid = {
    'max_df': np.arange(0.16, 0.17, 0.01),
    'min_df': np.arange(4, 5, 1),
}

best_params = {'max_df': None, 'min_df': None}
best_score = 0.0

num_iters = len(ParameterGrid(grid))

cnt = 0
for param_values in ParameterGrid(grid):
    # fit 
    for rs in np.arange(3, 10, 1):
        vectorizer = TfidfVectorizer(**param_values).fit(X_train)
        X_train_csr = vectorizer.transform(X_train)
        #lr = LogisticRegression().fit(X_train_csr, y_train)
        gbr = GradientBoostingRegressor(random_state=rs, n_estimators=best_n_es, max_depth=best_d).fit(X_train_csr, y_train)
        # predict
        X_test_csr = vectorizer.transform(X_test)
        y_pred = gbr.predict(X_test_csr)
        y_pred = [0 if i < 0.5 else 1 for i in y_pred]
        cur_score = f1_score(y_true, y_pred)
        if cur_score > best_score:
            best_score = cur_score
            best_params.update(param_values)
            best_rs = rs
        if cnt % 250 == 0:
            logging.info(
                'iteration: %d of %d; %s; best_score= %.4f',
                cnt, num_iters, param_values, best_score
            )
    cnt = cnt + 1
print('best params: %s, best_score %.4f', best_params, best_score, best_rs)
# Out:
# 2023-01-08 23:35:47,604 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8627
# 2023-01-08 23:36:30,057 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8637
# 2023-01-08 23:37:12,723 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8681
# 2023-01-08 23:37:55,237 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8681
# 2023-01-08 23:38:37,996 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8681
# 2023-01-08 23:39:20,386 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8681
# 2023-01-08 23:40:03,293 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8681
# best params: %s, best_score %.4f {'max_df': 0.16, 'min_df': 4} 0.8680688336520077 5

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']

grid = {
    'max_df': np.arange(0.16, 0.17, 0.01),
    'min_df': np.arange(4, 5, 1),
}

best_params = {'max_df': None, 'min_df': None}
best_score = 0.0

num_iters = len(ParameterGrid(grid))

cnt = 0
for param_values in ParameterGrid(grid):
    # fit 
    vectorizer = TfidfVectorizer(**param_values).fit(X_train)
    X_train_csr = vectorizer.transform(X_train)
    #lr = LogisticRegression().fit(X_train_csr, y_train)
    gbr = GradientBoostingRegressor(alpha=0.9, random_state=5, n_estimators=best_n_es, max_depth=best_d).fit(X_train_csr, y_train)
    # predict
    X_test_csr = vectorizer.transform(X_test)
    y_pred = gbr.predict(X_test_csr)
    y_pred = [0 if i < 0.5 else 1 for i in y_pred]
    cur_score = f1_score(y_true, y_pred)
    if cur_score > best_score:
        best_score = cur_score
        best_params.update(param_values)
        best_a = a
    if cnt % 250 == 0:
        logging.info(
            'iteration: %d of %d; %s; best_score= %.4f',
            cnt, num_iters, param_values, best_score
        )
    cnt = cnt + 1
print('best params: %s, best_score %.4f', best_params, best_score, best_a, best_rs, best_n_es, best_d)
# Out:
# 2023-01-09 00:35:31,196 iteration: 0 of 2; {'max_df': 0.16, 'min_df': 4}; best_score= 0.8681
# best params: %s, best_score %.4f {'max_df': 0.16, 'min_df': 4} 0.8680688336520077 0.9 5 500 8

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']


vectorizer = TfidfVectorizer(**param_values).fit(X_train)
X_train_csr = vectorizer.transform(X_train)
gbr = GradientBoostingRegressor(random_state=1, n_estimators=500, max_depth=8).fit(X_train_csr, y_train)
# predict
X_test_csr = vectorizer.transform(X_test)
y_pred = gbr.predict(X_test_csr)
y_pred = [0 if i < 0.5 else 1 for i in y_pred]
cur_score = f1_score(y_true, y_pred)

print('best params: %s, best_score %.4f', param_values, cur_score)
# Out:
# {'max_df': 0.16, 'min_df': 4}
# best params: %s, best_score %.4f {'max_df': 0.16, 'min_df': 4} 0.8675623800383877

# %%
import pickle

model = GradientBoostingRegressor(random_state=1, n_estimators=best_n_es, max_depth=best_d).fit(X_train_csr, y_train)

pkl_filename = "model.pkl" 
with open(pkl_filename, 'wb') as file: 
    pickle.dump(model, file)

# %%
vectorizer = TfidfVectorizer(**param_values).fit(X_train)

pkl_filename = "vectorizer.pkl" 
with open(pkl_filename, 'wb') as file: 
    pickle.dump(vectorizer, file)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import f1_score

import numpy as np
from sklearn.model_selection import ParameterGrid

X_train = train_df['msg'].values
y_train = train_df['label']

X_test = test_df['msg'].values
y_true = test_df['label']

X_train_csr = vectorizer.transform(X_train)
gbr = model
# predict
X_test_csr = vectorizer.transform(X_test)
y_pred = gbr.predict(X_test_csr)
y_pred = [0 if i < 0.5 else 1 for i in y_pred]
cur_score = f1_score(y_true, y_pred)

print('best_score %.4f', cur_score)
# Out:
# best_score %.4f 0.8675623800383877

# %%
df.reset_index(drop=True).rename(columns={'index': 'msg_id'}).head()
# Out:
#    msg_id                                                                                                                                                                                                                                                                                                                                                                                                                                                         msg  label subset
# 0       0                                                                                                                                                                                                                                                                    здравствуйте. ишу 2х спальную квартиру в лимассоле. желательно гермасойя. семья из 2х взрослых и 2х детей. без животных. на длительный срок, бюджет до 1000-1500 евро. предложения в лс.      0  train
# 1       1                                                                                                                                                                                                                                                                                                                                                                  #сниму  комнату в лимассоле или недалеко от него. с начала августа. любые предложения в лс      0  train
# 2       2                                                                                                                                                                                                                                                                                                                                                                                                                               мошенник риэлторским услугам.      0  train
# 3       3  **sales**    reg.1053 lic.489/e **stylish apartment with sea view  kissonerga. paphos** •total area: 85 m2  + balcony  •bedrooms:  2 •bathrooms: 1 **€ 120,000** we have a lot to offer  ================ **продажа**  reg.1053 lic.489/e **стильные апартаменты вид на море  •••kissonerga. пафос. ** •общая площадь: 85м2 + балкон •спальни: 2 •ванные комнаты: 1 **€ 120 000 ****+35726935826****  директ telegram 24/7** у нас есть что вам предложить      0  train
# 4       4                                                                                                                                                                                                                                                                                                                                     важно: [valerii korol](tg://user?id=193474890), если ты не бот и не спамер, пройди проверку, нажав на кнопку, где есть       0  train

# %%
df.reset_index(drop=True).rename(columns={'index': 'msg_id'}).to_csv('data/labeled_data_corpus2.csv', index=False)

# %%
df2 = pd.read_csv('data/labeled_data_corpus2.csv')
df2.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           msg  label
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    здравствуйте. ишу 2х спальную квартиру в лимассоле. желательно гермасойя. семья из 2х взрослых и 2х детей. без животных. на длительный срок, бюджет до 1000-1500 евро. предложения в лс.      0
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  #сниму  комнату в лимассоле или недалеко от него. с начала августа. любые предложения в лс      0
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               мошенник риэлторским услугам.      0
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  **sales**    reg.1053 lic.489/e **stylish apartment with sea view  kissonerga. paphos** •total area: 85 m2  + balcony  •bedrooms:  2 •bathrooms: 1 **€ 120,000** we have a lot to offer  ================ **продажа**  reg.1053 lic.489/e **стильные апартаменты вид на море  •••kissonerga. пафос. ** •общая площадь: 85м2 + балкон •спальни: 2 •ванные комнаты: 1 **€ 120 000 ****+35726935826****  директ telegram 24/7** у нас есть что вам предложить      0
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     важно: [valerii korol](tg://user?id=193474890), если ты не бот и не спамер, пройди проверку, нажав на кнопку, где есть       0
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           аренда  no: 367/e ️ларнака️между пила и декелия ️  в пешей доступности от моря. тихий район.  вилла  3 спальни,  3 санузла  просторная веранда с летней мебелью  открытого плана  кухня (духовка, вытяжка и кухонная плита, посудомоечная машинка стиральная машина и сушилка) бассейн отопление  крытая жилая площадь составляет около 300 кв.м. дом полностью обставлен современной мебелью.  цена: 2,100 евро. один депозит 2 предоплаты.  подробнее по телефону  +35797726055      0
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        привет  ищу виллу посуточно с бюджетом 2000€ в сутки от 1 до 3 дней с 11 по 15 августа примерно  вилла нужна для видеосъемки  любой город или посёлок  современный дизайн крайне важен пишите мне в личку или по номеру 95727146 юля      0
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              важно: [liss](tg://user?id=202814885), если ты не бот и не спамер, пройди проверку, нажав на кнопку, где есть       0
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      total messages: 126772      0
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               аренда  ️ларнака ️в центре города️ saint lazaro church ️  всё в пешей доступности до центральной набережной финекудес 5 минут.   no: 367/е   квартира  3 спальня  2 санузел  кухня открытого плана, все электро приборы стиральная машинка посудомоечная машинка  балконы  кондиционеры парковка    стоимость: 1.300 евро  торг уместен   подробнее по телефону  +35797726055      0
# 10                                                                                                                                                              аренда  ️ларнака ️макензи   расположенный в нескольких метрах от берега маккензи-бич в ларнаке,набережной, оживленной местами и ресторанами это четырехэтажное здание с 2 спальнями оснащено первоклассным дизайном и удобствами.   четырехэтажное закрытое здание (две квартиры на этаже) с отдельным входом.   высококачественная отделка из высококачественного европейского материала   крытые парковочные места (одно парковочное место на квартиру), доступ к которым осуществляется через парковочные ворота с дистанционным управлением.  кладовые  удобное расположение рядом с местными удобствами и достопримечательностями.  близость к пляжу маккензи (две минуты пешком) внутренняя площадь 90 кв.м плюс крытая веранда 27 кв.м, первый этаж  2 спальни и 2 ванные комнаты  год постройки 2022    цена: 1,900 евро в месяц  подробнее по телефону  +35797726055      0
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              #аренда долгосрочная **новое здание апартаментов **- 5 двуспальных апартаментов лимассол, гермасойа турист эрия  - прекрасная локация в пешей доступности до гипермаркета, кафе, банков и аптек, 13 минут пешком до пляжа дасуди и эвкалиптового парка, удобный выезд на главную дорогу; - новое здание, 5 двуспальных апартаментов; - полностью меблированы и оснащены техникой; - договор только на юридическое лицо.   цена аренды €13.500      1
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [alina](tg://user?id=5044643933), твоё сообщение удалено. причина: ссылка. я слежу за порядком в этом чате, по этой причине не даю возможность публиковать любые сообщения, где есть подозрительные ссылки. попробуй разместить своё сообщение / объявление без каких-либо ссылок.      0
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                     привет [philipp](tg://user?id=282606137)! это бесплатная группа по аренде и продаже недвижимости в республике кипр (длительно / посуточно - сдам / сниму)   размещай свои объявления с фотографиями (1-6 штук)   один объект - не чаще чем раз в 3 дня (не нужно спамить!)   посты только по теме группы, с указанием #сдам #сниму #ищу   указать город / курорт, где находится объект  ️невыполнение этих пунктов = бан   подобные группы у нас есть по разным [**странам мира  ](http://t.me/russian_groups)**купить рекламное место здесь - пишите @reklamaforum360      0
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        семья из двух человек ищет квартиру\апарты\дом в limassol. бюджет не более 1500 без животных готовы заехать после 16 августа работаем на кипре, все документы официальные (пинкслип в процессе) долгосрочная аренда      0
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            важно: [лилия](tg://user?id=817307264), если ты не бот и не спамер, пройди проверку, нажав на кнопку, где есть       0
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              важно: [evgeniia chikunova](tg://user?id=1105556253), если ты не бот и не спамер, пройди проверку, нажав на кнопку, где есть       0
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     sergihnoandgiovanni on viber rakuten !      0
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [philip jam ](tg://user?id=5511912145) has been banned! reason: [cas ban](https://cas.chat/query?u=5511912145).      0
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            **аренда | 3-сп квартира| 115 м2 | kanika enaerios, limassol | €2.500** уютные апартаменты на первой береговой линии • этаж: 7 • этажность: 7 • расстояние до моря — 100 м • вид на море • бытовая техника • мебель • кондиционирование воздуха • лифт • объект №49653 (видео) обращайтесь к нам для получения дополнительной информации (ru / eng / gr) https://dom.com.cy/catalog/rent/49653/      1
# 20                                                                                                                                                                                                                                                                                                                                            #аренда лимасол  цена 2800€ в месяц   потамос гермасоя недалеко от papas supermarket.  сдаётся в аренду отремонтированная полностью мобелированная 3х спальная квартира 130m² 3 спальни 1 ванна 2 туалета 2 балкона конденционеры во всех комнатах  электрическое отопление в пешей доступности вся инфраструктура.  до моря 750 метров. камин в рабочем состоянии. 2 спальни купят мебель по желанию клиента.(офисный стол,кровати и т.д) крытая парковка на 2 машины. квартира находится на 2 этаже, в здании 4 квартиры по 2 на каждом этаже.без лифта. без животных.   2 депозита 1 аренда.  chrisostomos papageorgiou estate rn186.ln56  tommy_s estate  больше информации по тел.99199676      1
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              здравствуйте!пришлите пожалуйста больше фото…      0
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   аренда. сдаётся мезонет в мазотосе. закрытый  комплекс с бассейном. 2 спальни,  2 туалета. есть мебель и необходимая  бытовая техника. парковочное место. магазины и рестораны в пешей доступности. от аэропорта ларнаки 20 минут. цена 600 евро. короткая аренда 1200. тел.+35799056232      0
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                      привет [alexey](tg://user?id=535455913)! это бесплатная группа по аренде и продаже недвижимости в республике кипр (длительно / посуточно - сдам / сниму)   размещай свои объявления с фотографиями (1-6 штук)   один объект - не чаще чем раз в 3 дня (не нужно спамить!)   посты только по теме группы, с указанием #сдам #сниму #ищу   указать город / курорт, где находится объект  ️невыполнение этих пунктов = бан   подобные группы у нас есть по разным [**странам мира  ](http://t.me/russian_groups)**купить рекламное место здесь - пишите @reklamaforum360      0
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                          привет [tatyana zheleznaya](tg://user?id=514130077)! это бесплатная группа по аренде и продаже недвижимости в республике кипр (длительно / посуточно - сдам / сниму)   размещай свои объявления с фотографиями (1-6 штук)   один объект - не чаще чем раз в 3 дня (не нужно спамить!)   посты только по теме группы, с указанием #сдам #сниму #ищу   указать город / курорт, где находится объект  ️невыполнение этих пунктов = бан   подобные группы у нас есть по разным [**странам мира  ](http://t.me/russian_groups)**купить рекламное место здесь - пишите @reklamaforum360      0
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [zosimidis taxi](tg://user?id=1489773933), your message was deleted      0
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       аренда  ️ларнака ️ tersefanou ️  пентхаус в комплексе.    комплекс с общим бассейном  2 спальни  балкон парковка крытая  кладовая ванная комната  крытая площадь 100м и 100м веранда.  цена: 900 евро в месяц    подробнее по телефону  +35797726055      0
# 27                                                                                                                                                                                                                                                                                                                                                 продается классная 3х спальная квартира  люксовый проект!  кипр, лимасол, агиас тихонас/параклиша tourist area     х спальная квартира в современном люксовом комплексе, в  туристической зоне в минутах ходьбы от пляжа.  этаж – 4ый; общая крытая площадь 203 кв.м.;  •крытая парковка;  •кладовая; •  отдельная кухня; - высокое качество строительства (класса люкс)! - пешая доступность к морю (400м)! - бассейн / сауна  - тренажерный зал  - игровые спортивные площадки; •титулы в наличие! •развитая инфраструктура стоимость 880 000 евро + ндс .    подходит под программу пмж  больше фото и видео обзор вышлю по запросу. по вопросам звоните/пишите+357 95570105 (whatsapp)      0
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [nano moran](tg://user?id=5516766428), you were banned (spam).      0
# 29                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           управляющая компания предлагает в аренду роскошную виллу в престижном районе агиос тихонас, недалеко от отеля four seanons и пляжа. дом 5002 на участке 900м2. у дома большой красивый сад, бассейн, барбекю зона. в прошлом году была заменена мебель на новую (люкс сегмент включая fendi), качественная техника, отопление, сауна. на втором этаже 4 спальни + ещё 4 на уровне бейзсмент. владелец запрашивает €8000 в месяц.      1
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...    ...
# 6512                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           аренда  ️ларнака ️alpha mega  no: 367/е   квартира  2 спальни  2 санузелa  кухня открытого плана, все электро приборы стиральная машинка и посудомоечная веранда  кондиционеры парковка крытая   стоимость: 1,500 евро с common expenses   подробнее по телефону  +35797726055      0
# 6513                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ищу квартиру в пафосе. 1-2 комнаты, до 1000 евро, район universal/центр, мебелированную, не 1 этаж планирую снимать с середины августа, но могу заехать чуть раньше      0
# 6514                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              можно фото?      0
# 6515                                                                                                                                                                                                                                                                                                                                                                       аренда потамос гермасойя, лимассол   **роскошный новый пентхаус с 4 спальнями в эксклюзивном комплексе, расположенном в тихом районе.** проект состоит из элитных квартир, отличается великолепным дизайном и современным архитектурным стилем.  комплекс включает в себя общий бассейн, парковочное место и благоустроенную территорию.   тихий район и близость к городской инфраструктуре создают идеальные условия для комфортного проживания.      крытая площадь, м2: 149,0  крытая веранда, м2: 65,3  терраса на крыше, м2: 97   расстояние до моря: 1500 м  **__цена - €7000/месяц + 2 депозита. **__  телефон - 95 965325  агент рег. 829 |  лиц. № 224/е      1
# 6516                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             добрый день! ищу 2-3 спальную квартиру/дом. лимассол. с детьми. без животных. бюджет до 1500      0
# 6517                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 #аренда #сдам #на длительный срок  ️️️сдам 2х спальную квартиру на нулевом этаже в одном из лучших комплексов пафоса, royal seacrest, два больших бассейна, детский бассейн, очень чистый и ухоженный  комплекс, квартира теплая, уютная, с мебелью, техникой , напротив нижнего kfc ,с 1 сентября на долгий срок:1500€ плюс два депозита.возможно с 20 июля, но отдельно обсуждается.пишите в личку.️️️      0
# 6518                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   добрый день! семья из двух человек ищет квартиру на долгих срок аренды. не выше 700, с одним депозитом, ларнака, любой район.  спасибо      0
# 6519                 добрый день! ищу квартиру в лимассоле на длительный срок (agia zoni, neapolis, в 5-10 минутах ходьбы от зоопарка)  бюджет в пределах 1200 €   пожелания:  ⁃ не старый дом   ⁃ не ground floor    ⁃ наличие всей мебели и бытовой техники  ⁃ отсутствие плесени  о себе: 21 год, работа в it сфере, снимать планирую один, без домашних животных, без вредных привычек  заезд возможен как сейчас, так и до середины сентября  контакты: в личных сообщениях +79190052853 в telegram, whatsapp, viber, местный номер для звонков +35795108110  спасибо!   hello!  looking for a long-term rent in limassol (agia zoni, neapolis, 5-10 minutes walk away from zoo)  budget within 1200 €  wishes:  ⁃ not an old building  ⁃ not ground floor  ⁃ fully furnished  ⁃ no mold  about myself: 21 years old, working in it, single, no pets, no bad habits  check-in in nearest future or in mid-september  please contact me in personal messages +79190052853 in telegram, whatsapp, viber, or call +35795108110   thank you!      0
# 6520  продажа, собственник  локация: лимассол, район germasogeia  продаются 4 квартиры в строящемся жилом комплексе bali residence в 500 метрах от парка дасуди и в 200 метрах от магазина papas. окончание строительства запланировано на октябрь 2022.  двухспальная квартира, расположенная на третьем этаже здания.  s квартиры: 87.54 м2,  s веранды: 30.97 м2 + парковочное место и кладовка.  цена 555,000 eur + vat (без торга)  односпальная квартира, расположенная на третьем этаже здания.  s квартиры: 55.17 м2,  s веранды: 16.32 м2  + парковочное место и кладовка.  цена 385,000 eur + vat (без торга)  односпальная квартира, расположенная на третьем этаже здания.  s квартиры: 53.89 м2,  s веранды: 12.75 м2  + парковочное место и кладовка.  цена 360,000 eur + vat (без торга)  пентхаус с тремя спальнями и личным бассейном на крыше, расположенный на четвертом этаже здания.  s квартиры: 113.43 м2, s крыши: 58.54 м2 (+16.06 м2 подсобка), s веранды: 28.70 м2  + парковочное место и кладовка.  цена: 945,...      0
# 6521                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    извините, цели спамить не имела. спасибо за понимание      0
# 6522                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             важно: [ulya](tg://user?id=3551938), если ты не бот и не спамер, пройди проверку, нажав на кнопку, где есть       0
# 6523                                                                                                                                                                                                                                                                                                                                                                                                                                                                      привет [леся](tg://user?id=167180483)! это бесплатная группа по аренде и продаже недвижимости в республике кипр (длительно / посуточно - сдам / сниму)   размещай свои объявления с фотографиями (1-6 штук)   один объект - не чаще чем раз в 3 дня (не нужно спамить!)   посты только по теме группы, с указанием #сдам #сниму #ищу   указать город / курорт, где находится объект  ️невыполнение этих пунктов = бан   подобные группы у нас есть по разным [**странам мира  ](http://t.me/russian_groups)**купить рекламное место здесь - пишите @reklamaforum360      0
# 6524                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                #аренда/пафос chloroka 3 спальная вилла кондиционеры солнечные панели большой балкон  комплекс закрытый,  охраняемый есть все для проживания бассейн на несколько домов на территории комплекса находится 2 игровых площадки   долгосрочная аренда 3100 €      0
# 6525                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      аренда лимасол   сдаётся в аренду 3х спальная квартира в районе агия фила. квартира 124m² 3 спальни 2 туалета 2 балкона полностью мебелированная камин конденционеры во всех комнатах. красивый чистый подъезд свободная парковка  тихое место с прекрасным видом.  можно с кошкой.  цена 2000 в месяц  1 депозит 2 аренды заселение в квартиру через 10 дней после внесения депозита  больше информации по тел.99199676. tommy_s estate rn186.ln56      1
# 6526                                                                                                                                               agent reg no: 758, license 410/e  3 спальни/ 3 ванных / лимассол/ гермассоя   цена € 4500 в месяц  аренда шикарной двухуровневой  3х комнатной квартиры в комплексе на первой линии с прямым видом.     общая площадь 135 кв.м.,   крытая терраса  -22 кв.м.    открытая терраса  45 кв.м.  3 спальни   3 ванные   просторная открытого плана гостиная/столовая,   кухня полностью оборудованная,  прачечная комната   - итальянская мебель  - тв с плоским экраном и каналами на русском и английском языках,  - высокоскоростной интернет  - ас инверторные  - солнечные панели   цена  4500 евро + вода и электроэнергия  интернет и common expenses, мусор и канализация.  включены в стомость.   контракт на год  два депозита + 1 месяц аренды   доступна с 7го октября.  домашние животные не разрешаются.   больше фото по запросу.   обращайтесь  надежда +35797821787 what_s app      1
# 6527                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            мы,семья из 2 взрослых, 1 ребенка и собаки, ищем 2-спальную квартиру в ларнаке , центр и рядом, цена до 1300€      0
# 6528                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       чуть выше зоопарка      0
# 6529                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       продам квартиру в лимассоле  двухэтажная квартира с верандой  в четырехэтажном доме с бассейном, садом, парковочных местом и с чудесным видом на горы и оливковую рощу 3 спальни 3 санузла большая веранда большая кладовая 5 минут до моря  +357 99 851078 оксана      0
# 6530                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          семейная пара без детей снимет 1/2-спальную квартиру в лимассоле. долгосрочно.  бюджет до €1000. рассмотрим разные варианты.  пожалуйста, пишите в личные сообщения. a married couple without children will rent a 1 or 2 bedroom apartment in limassol. long term.   budget up to €1000.  let_s consider different options.  please write in private messages.      0
# 6531                                                                                                                                                                                                                                                                                                                                                                                                #продажа – 3х спальный semi-detached дом продажа - специальное предложение!!! локация: кипр, лимасол, гермасойя турист  спецификация: площадь дома 140 м2 площадь участка 360 м2 на первом этаже - кухня, гостиная, туалет, выход на террасу.  на втором этаже - 3 спальни, ванная.  в комплексе с бассейном пешая доступность к морю  крытая парковка на 2 авто солнечные батареи нагрева воды  барбекю зона развитая инфраструктура / центровая локация!     титул в наличие; больше фото квартиры и видео обзор отправлю по запросу.  стоимость снижена - 450 000 евро. без ндс.  по вопросам звоните/пишите +357 95570105 (whatsapp).      0
# 6532                                                                                                               #продажа - успейте купить! продажа- новый 2-х спальный пентхаус локация: кипр, лимасол, неаполис  2х спальный пентхаус в новом современном комплексе, в центре туристической зоны в минутах ходьбы от пляжа. в доме всего 4 резиденции, по одной на этаже!  премиальная локация общая площадь 145,4 кв.м., в т.ч. крытая внутренняя площадь 77,1м2, крытая веранда 23,3м2, руф гарден 45м2. 2 спальни со своими санузлами (душ и ванна) +1 гостевой санузел очень хорошая, продуманная планировка квартиры  крытый паркинг кладовая комната блок кондиционирования vrv в гостиной, в спальнях сплит-системы современные стеклопакеты с москитными сетками электрические ролл ставни на окнах в спальнях отличная сантехника развитая инфраструктура высокий инвестиционный потенциал! ️стоимость всего 495 000 евро + ндс ️  торг уместен! подходит под программу пмж по вопросам звоните/пишите  +357 95570105 (whatsapp)      0
# 6533                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [stef l](tg://user?id=2079702082), you were banned (multiple warnings).      0
# 6534                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            **loel high rise residential: новый высотный проект в лимассоле** застройщик начал снос старых объектов на участке, где будет построен крупномасштабный жилой комплекс. https://dom.com.cy/live/digest-57929/      0
# 6535  #аренда пейя, район пафоса  **в долгосрочную аренду 2сп вилла с садом и бассейном в тихом районе пейи в 7 минутах езды от моря и в 20 минутах езды от центра пафоса.  2 **спальни на втором этаже , одна с двуспальной кроватью, другая с двумя односпальными, каждая спальная комната с собственной ванной и большой верандой. в каждой комнате имеются встроенные шкафы, кондиционеры воздуха. на первом этаже есть ванная комната с душевой кабиной и кладовая.  в гостиной на первом этаже виллы имеется два дивана. полностью оборудованная кухня-столовая с холодильником, кухонной плитой, духовкой и вытяжкой, имеется микроволновая печь, тостер, чайник, посудомоечная и стиральная машины, утюг и все, необходимые кухонные принадлежности. в гостиной имеется телевизионный уголок со спутниковым телевидением, wi-fi интернет. вилла располагает фруктовым (апельсин, лимон, персик и пр ) садом.   **__цена - €1300/месяц + €250 за обслуживание сада и бассейна. **__ будет доступна в конце августа.   телефон - 95 ...      0
# 6536                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   **rent** •reg.1053 lic.489/e ••**•paphos. universal**  •apartment 110sqm •bedroom’s :  2 •bathroom’s : 2 •fully furnished  **€ 1600   tel (357) 26935826 ** direct telegram 24/7 ================== **аренда** •reg.1053 lic.489 **•••paphos. kings avenue mall** .апартаменты 110м2 •спальни:  2 •ванные: 1 ••полностью меблирована **€ 1600  ****+35726935826**** ** директ telegram 24/7 больше информации в директ      1
# 6537                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                #продажа – 5 спальная вилла  лимасол (кипр)/ калогири                                                                общая площадь дома: 300+ кв.м площадь участка: 1100 кв.м  топовая локация! теплые полы! просторная кухня зона барбекю с террасой система орошения в саду   собственный бассейн на участке   дом продается со всей мебелью и бытовой техникой!  и многое другое!  титул: есть!!! больше фото и локацию вышлю по запросу!  спец цена!!! 2 600 000 евро. ндс нет.  по вопросам звоните/пишите +357 95570105. (whatsapp)      0
# 6538                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [anastasia kikel](tg://user?id=930668254), your message was deleted      0
# 6539                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        аренда/пафос  pano paphos  совершенно новые 3 спальные апартаменты  (150 кв.м.) кондиционеры  новая техника современный дизайн  высококачественные окна шумомзоляция солнечные панели  крытый паркинг  развитая инфраструктура  без мебели    долгосрочная аренда 1800€ с 1.10.22      0
# 6540                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             здравствуйте , дорогие друзья ! ищу бизнес для продвижения!  меня зовут сергей я таргетолог, smm специалист.  имею 5 лет опыта в продвижении бизнеса на рынке снг, европы и сша.     увеличиваю прибыль своим клиентам за счёт:  ⁃ красивой упаковки соцсетей  ⁃ привлечения новых заявок с помощью таргетированной рекламы и уникального контента   я заинтересован в качественном результате не меньше вас! я ставлю фокус на прибыли клиентов и долгосрочном сотрудничестве  пишите в лс       0
# 6541                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ищем квартиру в пафосе в аренду с середины августа нас двое: я и муж  обязательно:  - двухкомнатная,  - наличие или возможность установить посудомойку,  - возможность проживания с собакой (спаниель, приедет через пол года где-то , ничего не грызёт, не орёт, очень добрая) - от 1 года минимум, мы на пмж   желательно: - бассейн - крытая парковка  район не особо важен можно частично без мебели бюджет до 1000€      0
#
# [6542 rows x 2 columns]
